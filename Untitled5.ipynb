# %%
def atm():
    
    
    print("********************\nATM sistemine hoşgeldiniz\n********************")


    print("""
    İşlemler:

    1. Bakiye Sorgulama
    2. Para Yatırma
    3. Para Çekme

    Programdan 'q' tuşu ile çıkabilirsiniz.

    """)

    bakiye  = 1000 

    while True:
        
        işlem = input("İşlemi giriniz:")

        if (işlem == "q"):
            print("Yine bekleriz....")
            break
        elif (işlem == "1"):
            print("Bakiyeniz {} tldir".format(bakiye))
        elif (işlem == "2"):
            miktar = int(input("Yatırmak istediğiniz tutar:"))

            bakiye += miktar
        elif (işlem == "3"):
            miktar = int(input("Çekmek istediğiniz tutar:"))
            if (bakiye - miktar < 0 ):
                print("Bu kadar para çekemezsiniz...")
                print("Bakiyeniz {} tldir".format(bakiye))
                continue
            bakiye -= miktar

        else:
            print("Lütfen geçerli bir işlem giriniz.")



            
           
            
print("**********\nKullanıcı Girişi\n**********\n")



sys_kul_adı = "irşad"

sys_parola  = "12345" 
giriş_hakkı = 3
while True:
    kullanıcı_adı = input("Kullanıcı Adı:")
    parola = input("Parola:")

    if (kullanıcı_adı != sys_kul_adı and parola == sys_parola):
        print("Kullanıcı Adı Hatalı...")
        giriş_hakkı -= 1
        print("Giriş Hakkı: ", giriş_hakkı)
    elif (kullanıcı_adı == sys_kul_adı and parola != sys_parola):
        print("Parola Hatalı...")
        giriş_hakkı -= 1

        print("Giriş Hakkı: ", giriş_hakkı)
    elif (kullanıcı_adı != sys_kul_adı and parola != sys_parola):
        print("Kullanıcı Adı ve Parola Hatalı...")
        giriş_hakkı -= 1
        print("Giriş Hakkı: ", giriş_hakkı)

    else:
        print("başarılı giriş yaptınız...")
        for l in atm():
            print(l)
        break
        
    
        
        
            
        
        
    if (giriş_hakkı == 0 ):
        
            
        print("Giriş Hakkınız Bitti...")
        break
# Out:
# **********
# Kullanıcı Girişi
# **********
#
# Kullanıcı Adı:irşad
# Parola:12345
# başarılı giriş yaptınız...
# ********************
# ATM sistemine hoşgeldiniz
# ********************
#
#     İşlemler:
#
#     1. Bakiye Sorgulama
#     2. Para Yatırma
#     3. Para Çekme
#
#     Programdan 'q' tuşu ile çıkabilirsiniz.
#
#
# İşlemi giriniz:1
# Bakiyeniz 1000 tldir
# İşlemi giriniz:2
# Yatırmak istediğiniz tutar:1903
# İşlemi giriniz:1
# Bakiyeniz 2903 tldir
# İşlemi giriniz:3
# Çekmek istediğiniz tutar:3000
# Bu kadar para çekemezsiniz...
# Bakiyeniz 2903 tldir
# İşlemi giriniz:1
# Bakiyeniz 2903 tldir
# İşlemi giriniz:3
# Çekmek istediğiniz tutar:1800
# İşlemi giriniz:1
# Bakiyeniz 1103 tldir
# İşlemi giriniz:q
# Yine bekleriz....
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13148\2448941251.py in <module>
#      75     else:
#      76         print("başarılı giriş yaptınız...")
# ---> 77         for l in atm():
#      78             print(l)
#      79         break
#
# TypeError: 'NoneType' object is not iterable
